# %% [markdown]
# # Busca Tempo Medio de jogo
# Documentação da API: https://github.com/ScrappyCocco/HowLongToBeat-PythonAPI

# %%
# !pip install howlongtobeatpy
# Out:
# Collecting howlongtobeatpy
#   Downloading howlongtobeatpy-1.0.19-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: aiohttp~=3.12 in /usr/local/lib/python3.12/dist-packages (from howlongtobeatpy) (3.13.2)
# Requirement already satisfied: requests~=2.32 in /usr/local/lib/python3.12/dist-packages (from howlongtobeatpy) (2.32.4)
# Collecting aiounittest~=1.5 (from howlongtobeatpy)
#   Downloading aiounittest-1.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fake_useragent~=2.2 (from howlongtobeatpy)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: beautifulsoup4~=4.13 in /usr/local/lib/python3.12/dist-packages (from howlongtobeatpy) (4.13.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.12->howlongtobeatpy) (1.22.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from aiounittest~=1.5->howlongtobeatpy) (2.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4~=4.13->howlongtobeatpy) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4~=4.13->howlongtobeatpy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->howlongtobeatpy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->howlongtobeatpy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->howlongtobeatpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32->howlongtobeatpy) (2025.11.12)
# Downloading howlongtobeatpy-1.0.19-py3-none-any.whl (13 kB)
# Downloading aiounittest-1.5.0-py3-none-any.whl (7.0 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: fake_useragent, aiounittest, howlongtobeatpy
# Successfully installed aiounittest-1.5.0 fake_useragent-2.2.0 howlongtobeatpy-1.0.19

# %%
from howlongtobeatpy import HowLongToBeat
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def gerarDataFrame():

  colunas = [
       'Nome do jogo', 'Plataforma', 'Tempo médio',
       'Tempo 100%', 'Tempo Gasto', 'Status', 'Nota'
  ]

  planilha = pd.DataFrame(columns=colunas)
  return planilha

def atualizarDataFrame(diretorio):
    try:
      planilha = pd.read_csv(diretorio, sep=',', encoding='UTF-8')
    except:
      print(f'Caminho invalido! {diretorio}')
    return planilha

# %%
# Função busca jogo através da lib/API how long to beat
def BuscaJogo(nome):
  results = None;
  while results is None:
    # Procura o jogo pelo nome e ignora caixa alta ou baixa
    results = HowLongToBeat().search(nome, similarity_case_sensitive=False);
    if results is None:
      print('Erro, nenhum jogo com este nome foi encontrado!');

  print('Jogos encontrados com este nome: ')
  for i in range(len(results)) :
    print(f'n°:{i}, {results[i].game_name}');
  numero = int(input("Informe o número do jogo que deseja escolher, ou use -1 para cancelar: "));
  if numero >= 0:
    jogo_escolhido = results[numero]
    print(f'Jogo escolhido: {jogo_escolhido.game_name}')
    return jogo_escolhido;
  else:
    return -1;

# %%
def buscaTempoMedioJogo(jogo_escolhido):
  return jogo_escolhido.main_story;

# %%
# Função para inserir jogo na tabela, chumbado para ir na primeira linha
def inserirJogo(jogo, planilha):
  indice = len(planilha)
  planilha.at[indice,'Nome do jogo'] = jogo.game_name
  planilha.at[indice,'Plataforma'] = input('Informe a plataforma em que se comprou o jogo: ')
  planilha.at[indice, 'Tempo médio'] = jogo.main_story
  planilha.at[indice, 'Tempo 100%'] = jogo.completionist
  planilha.at[indice, 'Tempo Gasto'] = float(input('Quanto tempo foi gasto no jogo?Ex: em 25 minutos: 0.25 ou em 2 horas e meia: 2.30 '))
  estado = input('Qual o estado do jogo? 1 - Em espera, 2 - Baixado, 3 - Zerado : ')
  match estado:
    case '1':
      estado = 'Em espera'
    case '2':
      estado = 'Baixado'
    case '3':
      estado = 'Zerado'
    case _:
      print('Erro, estado incorreto!')
      estado = 'Não informado'
  planilha.at[indice, 'Status'] = estado
  planilha.at[indice, 'Nota'] = int(input('Informe a Nota para o jogo, ou digite -1 caso ainda não queira informar: '))
  if planilha.at[indice, 'Nota'] == -1:
    planilha.at[indice, 'Nota'] = '';

  planilha.head()

# %%
# Menu
operacao = int(input('Olá, informe qual operação deseja realizar:\n1 - criar planilha do zero, 2 - atualizar planilha'))
match operacao:
  case 1:
    dt = gerarDataFrame();
  case 2:
    dir = input('Informe o diretório da planilha')
    dt = atualizarDataFrame(dir)
    # to-do: erro ao adicionar segunda linha, esta

jogo = BuscaJogo(input('Nome do jogo: '))
inserirJogo(jogo, dt)
# Out:
# Olá, informe qual operação deseja realizar:
# 1 - criar planilha do zero, 2 - atualizar planilha1
# Nome do jogo: RaGnarok
# Jogos encontrados com este nome:
# n°:0, God of War: Ragnarök
# n°:1, God of War: Ragnarök - Valhalla
# n°:2, La Pucelle: Ragnarok
# n°:3, Ragnarok DS
# n°:4, Zed Blade
# n°:5, Ragnarok Odyssey Ace
# n°:6, Ragnarok V: Returns
# n°:7, Ragnarok Clicker
# n°:8, Doki Doki Ragnarok
# n°:9, Ragnarok Tactics
# n°:10, Battletoads in Ragnarok's World
# n°:11, Ragnarok Online
# n°:12, Ragnarok Re:Start
# n°:13, Titan Quest: Ragnarök
# Informe o número do jogo que deseja escolher: 0
# Jogo escolhido: God of War: Ragnarök
# Informe a plataforma em que se comprou o jogo: PS4
# Quanto tempo foi gasto no jogo?Ex: em 25 minutos: 0.25 ou em 2 horas e meia: 2.30 15
# Qual o estado do jogo? 1 - Em espera, 2 - Baixado, 3 - Zerado : 2
# Informe a Nota para o jogo, ou digite -1 caso ainda não queira informar: 9

# %%
# Continuação do Menu
opc = 'Y'
opc = input('Deseja adicionar mais jogos? Y=Sim, N=Não')
while opc == 'Y':
  jogo = BuscaJogo(input('Nome do jogo: '))
  if jogo != -1:
    inserirJogo(jogo, dt)
  opc = input('Deseja adicionar mais jogos? Y=Sim, N=Não')
else:
  print('Gerando o arquivo csv...')
  dt.to_csv('/content/drive/MyDrive/Python/teste_backlog.csv', header=True, index=False)
  print('Arquivo gerado em /content/drive/MyDrive/jogos/')
# Out:
# Deseja adicionar mais jogos? Y=Sim, N=NãoY
# Nome do jogo: Assassin
# Jogos encontrados com este nome:
# n°:0, Assassin
# n°:1, Assassin's Creed Odyssey
# n°:2, Assassin's Creed Origins
# n°:3, Assassin's Creed II
# n°:4, Assassin's Creed IV: Black Flag
# n°:5, Assassin's Creed Valhalla
# n°:6, Assassin's Creed
# n°:7, Assassin's Creed Shadows
# n°:8, Assassin's Creed: Syndicate
# n°:9, Assassin's Creed: Unity
# n°:10, Assassin's Creed: Brotherhood
# n°:11, Assassin's Creed Mirage
# n°:12, Assassin's Creed III: Remastered
# n°:13, Assassin's Creed: Revelations
# n°:14, Assassin's Creed: Rogue
# n°:15, Hitman 2: Silent Assassin
# n°:16, Assassin's Creed III
# n°:17, Assassin's Creed III: Liberation
# n°:18, Assassin's Creed: Freedom Cry
# Informe o número do jogo que deseja escolher: 3
# Jogo escolhido: Assassin's Creed II
# Informe a plataforma em que se comprou o jogo: PC
# Quanto tempo foi gasto no jogo?Ex: em 25 minutos: 0.25 ou em 2 horas e meia: 2.30 15
# Qual o estado do jogo? 1 - Em espera, 2 - Baixado, 3 - Zerado : 3
# Informe a Nota para o jogo, ou digite -1 caso ainda não queira informar: 10
# Deseja adicionar mais jogos? Y=Sim, N=NãoY
# Nome do jogo: Assassins
# Jogos encontrados com este nome:
# n°:0, The Witcher 2: Assassins of Kings
# n°:1, Assassin's Creed Odyssey
# n°:2, Assassin's Creed Origins
# n°:3, Assassin's Creed II
# n°:4, Assassin's Creed IV: Black Flag
# n°:5, Assassin's Creed Valhalla
# n°:6, Assassin's Creed
# n°:7, Assassin's Creed Shadows
# n°:8, Assassin's Creed: Syndicate
# n°:9, Assassin's Creed: Unity
# n°:10, Assassin's Creed: Brotherhood
# n°:11, Assassin's Creed Mirage
# n°:12, Assassin's Creed III: Remastered
# n°:13, Assassin's Creed: Revelations
# n°:14, Assassin's Creed: Rogue
# n°:15, Assassin's Creed III
# n°:16, Assassin's Creed III: Liberation
# n°:17, Assassin's Creed: Freedom Cry
# n°:18, Assassin's Creed Chronicles: China
# n°:19, Assassin's Creed: The Ezio Collection
# Informe o número do jogo que deseja escolher: -1
# Deseja adicionar mais jogos? Y=Sim, N=NãoN
# Gerando o arquivo csv...
# Arquivo gerado em /content/drive/MyDrive/jogos/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# def deletarJogo(name):
#   for n in range(len(planilha)):
#     nomes = planilha.at[n, 'A']
#     # if name in nomes:
#     print(nomes)
# deletarJogo('Lollypop')

# %%
# Busca planilha com dados
import gspread
import pandas as pd
from google.auth import default
from google.colab import auth
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)
spreadsheet = gc.open_by_key('1zo9ngJRiM4LbjKnjvUFBID-rXQl1Nvx6MiBhLuxXLAE')
worksheet = spreadsheet.get_worksheet(0)
df = pd.DataFrame(worksheet.get("A1:A22"))
# Code for making the first row as header. Remove if not needed.
df.columns = df.iloc[0]
df = df.drop(0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-510080684.py in <cell line: 0>()
#       4 from google.auth import default
#       5 from google.colab import auth
# ----> 6 auth.authenticate_user()
#       7 creds, _ = default()
#       8 gc = gspread.authorize(creds)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
lista = df['Jogo'].to_numpy();
for i in lista:
  jogo = BuscaJogo(i);
  print(f'Tempo Médio: {jogo.main_story}\n Tempo para 100%: {jogo.completionist}');
